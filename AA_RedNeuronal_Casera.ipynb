# %% [markdown]
# <a href="https://colab.research.google.com/github/lourdesvaca/repository-algoritmica-avanzada-2023-2/blob/algoritmica-avanzada/AA_RedNeuronal_Casera.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Redes neuronales

# %% [markdown]
# La red neuronal solo realiza una sola cosa
#
# Para realizar otra cosa o n cosas, se debe de crear una red neuronal distinta y en base a eso podemos trabajar con ambas

# %% [markdown]
# ####El perceptrón
# Tiene conexiones de entrada y salida
#
# Tiene N valores de entrada y producen 1 única salida
#
# la unidad más básica, neurona, tiene una única salida que es 1 o 0.
#
# Luego de los valores de entrada se produce algo llamados *pesos sinápticos*, estos pesos determinan la importancia a esos valores. Estos pesos graduan el nivel de importancia, este nivel influye al momento de obtener el valor de salida.
#
# En el área de *unión sumadora* se suman los valores
#
# En el área de *función de activación* se estandariza un valor (de escala n) en 0 o 1
#
# En el área de *salida*, obtenemos la salida.

# %% [markdown]
# ###La regla Delta o Corrección del Error
# gradiente de descenso=grado que desciende
#
# Se busca que el error decaíga, mientras tienda a 0, mejor.
#
# Forwardpass & backpropagation = hacia delante en los valores, hacia atrás

# %% [markdown]
# ###Funciones de activación
# * Identidad
# * Escalon
# * Lineal o tramos
# * Sigmoidea
# * Gaussiana
# * Sinusoidal
# La función sinousoidal tener cuidado al aplicarla
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# La cantidad de capas determina qué tipo de red neuronal es

# %%
from sklearn.datasets import make_circles

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 1. Generamos un dataset
#
# * utilizamos las variables 'x' e 'y' (x es un conjunto de valores, y es un conjunto de etiquetas)
# * utilizamos la función make_circles()
# * n_samples toma el valor de **

# %%
x,y = make_circles(n_samples=600, noise=1, factor=0.9)
#n_samples es el número de elementos (filas) que se visualizaran en el mapita | noise es el ruido (juego con el valor 0.1-1, 0-100%) | factor es la medida de separación entre los 2 círculos

# %%
plt.scatter(x[:,0], x[:,1])
plt.show()

# %% [markdown]
# El ruido hace referencia a la dispersión de los datos. Mucho ruido es igual a valores más dispersos.

# %%
x
# Out:
# array([[ 0.7310849 ,  2.24164242],
#        [ 0.36927969,  0.17151776],
#        [ 0.58542658, -0.75816766],
#        ...,
#        [-0.01923349,  0.30537955],
#        [-1.85194563, -0.6513744 ],
#        [ 0.37545316, -1.59412849]])
