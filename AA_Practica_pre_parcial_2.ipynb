# %% [markdown]
# <a href="https://colab.research.google.com/github/lourdesvaca/repository-algoritmica-avanzada-2023-2/blob/algoritmica-avanzada/AA_Practica_pre_parcial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Repaso
#
# Parcial 2, Algoritmica Avanzada. 2023-2

# %%
#libreria para el entrenamiento del modelo
from sklearn.model_selection import train_test_split
#libreria para el modelo: kneighbors
#from sklearn.neighbors import KNeighborsClassifier
from sklearn import neighbors

#libreria para el modelo: decisionTree
from sklearn.tree import DecisionTreeClassifier

#libreria para el modelo: random forest
from sklearn.ensemble import RandomForestClassifier

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('BankChurners.csv')

# %%
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School        Unknown  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# 0                  39  ...       12691.0                  777
# 1                  44  ...        8256.0                  864
# 2                  36  ...        3418.0                    0
# 3                  34  ...        3313.0                 2517
# 4                  21  ...        4716.0                    0
# ...               ...  ...           ...                  ...
# 10122              40  ...        4003.0                 1851
# 10123              25  ...        4277.0                 2186
# 10124              36  ...        5409.0                    0
# 10125              36  ...        5281.0                    0
# 10126              25  ...       10388.0                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0              11914.0                 1.335             1144              42
# 1               7392.0                 1.541             1291              33
# 2               3418.0                 2.594             1887              20
# 3                796.0                 1.405             1171              20
# 4               4716.0                 2.175              816              28
# ...                ...                   ...              ...             ...
# 10122           2152.0                 0.703            15476             117
# 10123           2091.0                 0.804             8764              69
# 10124           5409.0                 0.819            10291              60
# 10125           5281.0                 0.535             8395              62
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
# [10127 rows x 23 columns]

# %%
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...       12691.0                  777          11914.0
# 1              44  ...        8256.0                  864           7392.0
# 2              36  ...        3418.0                    0           3418.0
# 3              34  ...        3313.0                 2517            796.0
# 4              21  ...        4716.0                    0           4716.0
#
#    Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  \
# 0                 1.335             1144              42                1.625
# 1                 1.541             1291              33                3.714
# 2                 2.594             1887              20                2.333
# 3                 1.405             1171              20                2.333
# 4                 2.175              816              28                2.500
#
#    Avg_Utilization_Ratio  \
# 0                  0.061
# 1                  0.105
# 2                  0.000
# 3                  0.760
# 4                  0.000
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                           0.000093
# 1                                           0.000057
# 2                                           0.000021
# 3                                           0.000134
# 4                                           0.000022
#
#    Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 0                                            0.99991
# 1                                            0.99994
# 2                                            0.99998
# 3                                            0.99987
# 4                                            0.99998
#
# [5 rows x 23 columns]

# %%
df.tail()
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123         Unknown       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate        Unknown     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  \
# 10122              40  ...        4003.0                 1851
# 10123              25  ...        4277.0                 2186
# 10124              36  ...        5409.0                    0
# 10125              36  ...        5281.0                    0
# 10126              25  ...       10388.0                 1961
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 10122           2152.0                 0.703            15476             117
# 10123           2091.0                 0.804             8764              69
# 10124           5409.0                 0.819            10291              60
# 10125           5281.0                 0.535             8395              62
# 10126           8427.0                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
# [5 rows x 23 columns]

# %%
df.dtypes
# Out:
# CLIENTNUM                                                                                                                               int64
# Attrition_Flag                                                                                                                         object
# Customer_Age                                                                                                                            int64
# Gender                                                                                                                                 object
# Dependent_count                                                                                                                         int64
# Education_Level                                                                                                                        object
# Marital_Status                                                                                                                         object
# Income_Category                                                                                                                        object
# Card_Category                                                                                                                          object
# Months_on_book                                                                                                                          int64
# Total_Relationship_Count                                                                                                                int64
# Months_Inactive_12_mon                                                                                                                  int64
# Contacts_Count_12_mon                                                                                                                   int64
# Credit_Limit                                                                                                                          float64
# Total_Revolving_Bal                                                                                                                     int64
# Avg_Open_To_Buy                                                                                                                       float64
# Total_Amt_Chng_Q4_Q1                                                                                                                  float64
# Total_Trans_Amt                                                                                                                         int64
# Total_Trans_Ct                                                                                                                          int64
# Total_Ct_Chng_Q4_Q1                                                                                                                   float64
# Avg_Utilization_Ratio                                                                                                                 float64
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1    float64
# Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2    float64
# dtype: object

# %%
df.Attrition_Flag.unique()
# Out:
# array(['Existing Customer', 'Attrited Customer'], dtype=object)

# %%
df.Gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df.Education_Level.unique()
# Out:
# array(['High School', 'Graduate', 'Uneducated', 'Unknown', 'College',
#        'Post-Graduate', 'Doctorate'], dtype=object)

# %%
df.Marital_Status.unique()
# Out:
# array(['Married', 'Single', 'Unknown', 'Divorced'], dtype=object)

# %%
df.c.unique()
# Out:
# array(['$60K - $80K', 'Less than $40K', '$80K - $120K', '$40K - $60K',
#        '$120K +', 'Unknown'], dtype=object)

# %%
df.Card_Category.unique()
# Out:
# array(['Blue', 'Gold', 'Silver', 'Platinum'], dtype=object)

# %% [markdown]
# Eliminamos las últimas dos columnas

# %%
df.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis=1, inplace=True)

# %% [markdown]
# Mapeamos las columnas categóricas que contiene el dataset

# %%
#forma 1
df['Attrition_Flag'] = df.Attrition_Flag.map({'Existing Customer': 1, 'Attrited Customer': 2})

# %%
#forma 2
df.Gender = df.Gender.map({'M': 1, 'F':2})

# %%
df.Education_Level = df.Education_Level.map({'High School':1 , 'Graduate':2, 'Uneducated':3, 'Unknown':4, 'College':5,'Post-Graduate':6, 'Doctorate':7})

# %%
df['Marital_Status'] = df.Marital_Status.map({'Married':1, 'Single':2, 'Unknown':3, 'Divorced':4})

# %%
df.Card_Category = df.Card_Category.map({'Blue':1, 'Gold':2, 'Silver':3, 'Platinum':4})

# %%
df.describe()
# Out:
#           CLIENTNUM  Attrition_Flag  Customer_Age        Gender  \
# count  1.012700e+04    10127.000000  10127.000000  10127.000000
# mean   7.391776e+08        1.160660     46.325960      1.529081
# std    3.690378e+07        0.367235      8.016814      0.499178
# min    7.080821e+08        1.000000     26.000000      1.000000
# 25%    7.130368e+08        1.000000     41.000000      1.000000
# 50%    7.179264e+08        1.000000     46.000000      2.000000
# 75%    7.731435e+08        1.000000     52.000000      2.000000
# max    8.283431e+08        2.000000     73.000000      2.000000
#
#        Dependent_count  Education_Level  Marital_Status  Card_Category  \
# count     10127.000000     10127.000000    10127.000000   10127.000000
# mean          2.346203         2.974622        1.758862       1.126987
# std           1.298908         1.680730        0.879864       0.482019
# min           0.000000         1.000000        1.000000       1.000000
# 25%           1.000000         2.000000        1.000000       1.000000
# 50%           2.000000         2.000000        2.000000       1.000000
# 75%           3.000000         4.000000        2.000000       1.000000
# max           5.000000         7.000000        4.000000       4.000000
#
#        Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# count    10127.000000              10127.000000            10127.000000
# mean        35.928409                  3.812580                2.341167
# std          7.986416                  1.554408                1.010622
# min         13.000000                  1.000000                0.000000
# 25%         31.000000                  3.000000                2.000000
# 50%         36.000000                  4.000000                2.000000
# 75%         40.000000                  5.000000                3.000000
# max         56.000000                  6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000

# %%
df.dtypes
# Out:
# CLIENTNUM                     int64
# Attrition_Flag                int64
# Customer_Age                  int64
# Gender                        int64
# Dependent_count               int64
# Education_Level               int64
# Marital_Status                int64
# Income_Category              object
# Card_Category                 int64
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %% [markdown]
# Eliminamos las tablas que vemos necesarias

# %%
data = df.drop(['CLIENTNUM'], axis=1)

# %%
data.describe()
# Out:
#        Attrition_Flag  Customer_Age        Gender  Dependent_count  \
# count    10127.000000  10127.000000  10127.000000     10127.000000
# mean         1.160660     46.325960      1.529081         2.346203
# std          0.367235      8.016814      0.499178         1.298908
# min          1.000000     26.000000      1.000000         0.000000
# 25%          1.000000     41.000000      1.000000         1.000000
# 50%          1.000000     46.000000      2.000000         2.000000
# 75%          1.000000     52.000000      2.000000         3.000000
# max          2.000000     73.000000      2.000000         5.000000
#
#        Education_Level  Marital_Status  Card_Category  Months_on_book  \
# count     10127.000000    10127.000000   10127.000000    10127.000000
# mean          2.974622        1.758862       1.126987       35.928409
# std           1.680730        0.879864       0.482019        7.986416
# min           1.000000        1.000000       1.000000       13.000000
# 25%           2.000000        1.000000       1.000000       31.000000
# 50%           2.000000        2.000000       1.000000       36.000000
# 75%           4.000000        2.000000       1.000000       40.000000
# max           7.000000        4.000000       4.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# 50%                    4.000000                2.000000
# 75%                    5.000000                3.000000
# max                    6.000000                6.000000
#
#        Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# count           10127.000000  10127.000000         10127.000000
# mean                2.455317   8631.953698          1162.814061
# std                 1.106225   9088.776650           814.987335
# min                 0.000000   1438.300000             0.000000
# 25%                 2.000000   2555.000000           359.000000
# 50%                 2.000000   4549.000000          1276.000000
# 75%                 3.000000  11067.500000          1784.000000
# max                 6.000000  34516.000000          2517.000000
#
#        Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# count     10127.000000          10127.000000     10127.000000    10127.000000
# mean       7469.139637              0.759941      4404.086304       64.858695
# std        9090.685324              0.219207      3397.129254       23.472570
# min           3.000000              0.000000       510.000000       10.000000
# 25%        1324.500000              0.631000      2155.500000       45.000000
# 50%        3474.000000              0.736000      3899.000000       67.000000
# 75%        9859.000000              0.859000      4741.000000       81.000000
# max       34516.000000              3.397000     18484.000000      139.000000
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# count         10127.000000           10127.000000
# mean              0.712222               0.274894
# std               0.238086               0.275691
# min               0.000000               0.000000
# 25%               0.582000               0.023000
# 50%               0.702000               0.176000
# 75%               0.818000               0.503000
# max               3.714000               0.999000

# %% [markdown]
# ###Tabla de correlación
#
# Hacemos uso de esta tabla para identificar la relación entre columna y columna

# %%
corr = round(data.corr(), 4)
corr.style.background_gradient()
# Out:
# <ipython-input-31-b95318f4a440>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = round(data.corr(), 4)
# <style type="text/css">
# #T_c1cf0_row0_col0, #T_c1cf0_row1_col1, #T_c1cf0_row2_col2, #T_c1cf0_row3_col3, #T_c1cf0_row4_col4, #T_c1cf0_row5_col5, #T_c1cf0_row6_col6, #T_c1cf0_row7_col7, #T_c1cf0_row8_col8, #T_c1cf0_row9_col9, #T_c1cf0_row10_col10, #T_c1cf0_row11_col11, #T_c1cf0_row11_col13, #T_c1cf0_row12_col12, #T_c1cf0_row13_col11, #T_c1cf0_row13_col13, #T_c1cf0_row14_col14, #T_c1cf0_row15_col15, #T_c1cf0_row16_col16, #T_c1cf0_row17_col17, #T_c1cf0_row18_col18 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_c1cf0_row0_col1, #T_c1cf0_row0_col3, #T_c1cf0_row4_col10, #T_c1cf0_row11_col14 {
#   background-color: #ece7f2;
#   color: #000000;
# }
# #T_c1cf0_row0_col2, #T_c1cf0_row5_col18, #T_c1cf0_row13_col16, #T_c1cf0_row17_col15 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_c1cf0_row0_col4, #T_c1cf0_row5_col9, #T_c1cf0_row8_col5, #T_c1cf0_row10_col5, #T_c1cf0_row14_col7, #T_c1cf0_row16_col1, #T_c1cf0_row16_col7, #T_c1cf0_row17_col5, #T_c1cf0_row17_col10 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_c1cf0_row0_col5, #T_c1cf0_row4_col5, #T_c1cf0_row7_col14, #T_c1cf0_row8_col3, #T_c1cf0_row10_col3 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_c1cf0_row0_col6, #T_c1cf0_row11_col3, #T_c1cf0_row13_col3, #T_c1cf0_row13_col12 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_c1cf0_row0_col7, #T_c1cf0_row2_col6, #T_c1cf0_row4_col1, #T_c1cf0_row11_col5, #T_c1cf0_row12_col3, #T_c1cf0_row13_col5 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# #T_c1cf0_row0_col8, #T_c1cf0_row10_col17, #T_c1cf0_row11_col10, #T_c1cf0_row15_col0, #T_c1cf0_row15_col14, #T_c1cf0_row16_col5, #T_c1cf0_row18_col14 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_c1cf0_row0_col9, #T_c1cf0_row2_col12 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_c1cf0_row0_col10, #T_c1cf0_row0_col11, #T_c1cf0_row9_col11, #T_c1cf0_row12_col16, #T_c1cf0_row16_col17 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_c1cf0_row0_col12, #T_c1cf0_row0_col14, #T_c1cf0_row0_col16, #T_c1cf0_row0_col17, #T_c1cf0_row1_col3, #T_c1cf0_row1_col5, #T_c1cf0_row3_col1, #T_c1cf0_row3_col7, #T_c1cf0_row8_col15, #T_c1cf0_row11_col2, #T_c1cf0_row12_col4, #T_c1cf0_row12_col9, #T_c1cf0_row13_col2, #T_c1cf0_row13_col18, #T_c1cf0_row15_col8, #T_c1cf0_row16_col0, #T_c1cf0_row16_col9, #T_c1cf0_row16_col10, #T_c1cf0_row17_col9, #T_c1cf0_row18_col6, #T_c1cf0_row18_col11, #T_c1cf0_row18_col13 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c1cf0_row0_col13, #T_c1cf0_row1_col13 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_c1cf0_row0_col15, #T_c1cf0_row6_col3, #T_c1cf0_row6_col10, #T_c1cf0_row15_col3 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_c1cf0_row0_col18, #T_c1cf0_row3_col17 {
#   background-color: #d4d4e8;
#   color: #000000;
# }
# #T_c1cf0_row1_col0, #T_c1cf0_row3_col0, #T_c1cf0_row5_col0, #T_c1cf0_row18_col17 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_c1cf0_row1_col2, #T_c1cf0_row3_col16, #T_c1cf0_row4_col2, #T_c1cf0_row12_col15, #T_c1cf0_row18_col8 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_c1cf0_row1_col4, #T_c1cf0_row7_col3, #T_c1cf0_row7_col4, #T_c1cf0_row7_col5, #T_c1cf0_row8_col4, #T_c1cf0_row9_col4, #T_c1cf0_row10_col4, #T_c1cf0_row14_col4, #T_c1cf0_row16_col4, #T_c1cf0_row18_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c1cf0_row1_col6, #T_c1cf0_row9_col1, #T_c1cf0_row9_col6, #T_c1cf0_row9_col10, #T_c1cf0_row10_col16 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_c1cf0_row1_col7, #T_c1cf0_row7_col1 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_c1cf0_row1_col8 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_c1cf0_row1_col9, #T_c1cf0_row2_col14, #T_c1cf0_row4_col7, #T_c1cf0_row6_col1, #T_c1cf0_row6_col5, #T_c1cf0_row10_col1 {
#   background-color: #f1ebf5;
#   color: #000000;
# }
# #T_c1cf0_row1_col10, #T_c1cf0_row5_col3, #T_c1cf0_row18_col1 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_c1cf0_row1_col11, #T_c1cf0_row3_col18, #T_c1cf0_row4_col11, #T_c1cf0_row11_col16, #T_c1cf0_row15_col6, #T_c1cf0_row17_col11 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_c1cf0_row1_col12, #T_c1cf0_row1_col16, #T_c1cf0_row6_col17, #T_c1cf0_row8_col12 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_c1cf0_row1_col14, #T_c1cf0_row2_col5, #T_c1cf0_row9_col5, #T_c1cf0_row17_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_c1cf0_row1_col15, #T_c1cf0_row6_col12, #T_c1cf0_row11_col17 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_c1cf0_row1_col17, #T_c1cf0_row4_col17, #T_c1cf0_row7_col12, #T_c1cf0_row13_col17 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_c1cf0_row1_col18, #T_c1cf0_row4_col13, #T_c1cf0_row7_col13, #T_c1cf0_row12_col11, #T_c1cf0_row14_col13, #T_c1cf0_row16_col18, #T_c1cf0_row17_col16 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_c1cf0_row2_col0, #T_c1cf0_row5_col2, #T_c1cf0_row10_col8, #T_c1cf0_row17_col2 {
#   background-color: #c0c9e2;
#   color: #000000;
# }
# #T_c1cf0_row2_col1, #T_c1cf0_row5_col10, #T_c1cf0_row7_col10, #T_c1cf0_row12_col1, #T_c1cf0_row13_col14 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_c1cf0_row2_col3, #T_c1cf0_row2_col7, #T_c1cf0_row8_col1, #T_c1cf0_row8_col6, #T_c1cf0_row9_col3, #T_c1cf0_row11_col7, #T_c1cf0_row12_col7, #T_c1cf0_row13_col7, #T_c1cf0_row15_col5, #T_c1cf0_row17_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_c1cf0_row2_col4, #T_c1cf0_row3_col4, #T_c1cf0_row3_col9 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_c1cf0_row2_col8, #T_c1cf0_row8_col17, #T_c1cf0_row9_col8, #T_c1cf0_row14_col12 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_c1cf0_row2_col9, #T_c1cf0_row5_col1, #T_c1cf0_row5_col7, #T_c1cf0_row14_col1, #T_c1cf0_row15_col7 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_c1cf0_row2_col10, #T_c1cf0_row3_col10, #T_c1cf0_row8_col16, #T_c1cf0_row10_col14 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_c1cf0_row2_col11, #T_c1cf0_row4_col9 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_c1cf0_row2_col13, #T_c1cf0_row6_col7, #T_c1cf0_row12_col0, #T_c1cf0_row16_col8, #T_c1cf0_row17_col7 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_c1cf0_row2_col15, #T_c1cf0_row6_col2, #T_c1cf0_row9_col16, #T_c1cf0_row11_col12 {
#   background-color: #d2d3e7;
#   color: #000000;
# }
# #T_c1cf0_row2_col16, #T_c1cf0_row12_col13 {
#   background-color: #b9c6e0;
#   color: #000000;
# }
# #T_c1cf0_row2_col17, #T_c1cf0_row3_col8, #T_c1cf0_row7_col15, #T_c1cf0_row9_col15 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_c1cf0_row2_col18 {
#   background-color: #6ba5cd;
#   color: #f1f1f1;
# }
# #T_c1cf0_row3_col2, #T_c1cf0_row4_col0, #T_c1cf0_row15_col17 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_c1cf0_row3_col5 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_c1cf0_row3_col6, #T_c1cf0_row4_col12, #T_c1cf0_row9_col17 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_c1cf0_row3_col11, #T_c1cf0_row14_col18 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_c1cf0_row3_col12, #T_c1cf0_row11_col8, #T_c1cf0_row13_col8 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_c1cf0_row3_col13, #T_c1cf0_row8_col18 {
#   background-color: #9fbad9;
#   color: #000000;
# }
# #T_c1cf0_row3_col14, #T_c1cf0_row5_col14, #T_c1cf0_row8_col7, #T_c1cf0_row9_col14, #T_c1cf0_row10_col7, #T_c1cf0_row12_col10, #T_c1cf0_row18_col7, #T_c1cf0_row18_col10 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_c1cf0_row3_col15, #T_c1cf0_row12_col2, #T_c1cf0_row14_col16, #T_c1cf0_row16_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_c1cf0_row4_col3, #T_c1cf0_row6_col14, #T_c1cf0_row16_col14, #T_c1cf0_row17_col3 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_c1cf0_row4_col6, #T_c1cf0_row14_col6 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_c1cf0_row4_col8, #T_c1cf0_row4_col15, #T_c1cf0_row5_col8, #T_c1cf0_row7_col8, #T_c1cf0_row11_col0, #T_c1cf0_row16_col12 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_c1cf0_row4_col14, #T_c1cf0_row7_col9, #T_c1cf0_row11_col1, #T_c1cf0_row13_col1, #T_c1cf0_row14_col10 {
#   background-

# %% [markdown]
# Separamos la data
#
# data_x
#
# data_Y

# %%
data_x = data.drop([''], axis='columns') #aqui guardo todas las columnas con las que voy a entrenar al modelo
data_x = data."****" #aqui va el nombre de la columna objetivo
